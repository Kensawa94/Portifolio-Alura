# %%
import pandas as pd
from zipfile import ZipFile



caminho = "/content/drive/MyDrive/Bootcamp_ALURA/Portifolio-Alura/Diário/Módulo 3/Bases de Dados/PeNSE_2015_AMOSTRA2.zip"
zip = ZipFile(caminho)
caminho_pasta_zipada = zip.namelist()[1]

dados = pd.read_csv(zip.open(caminho_pasta_zipada), sep = ";", thousands = ".", decimal = ",")
dados.head()
# Out:
#    ANOPESQ  PAIS  REGEOGR  VB00004  VB01001  ...  V0008  V0041  aluno  escola  turma
# 0     2015    76        1        1        2  ...      4      1      1       1    296
# 1     2015    76        1        1        2  ...      4      1      2       1    296
# 2     2015    76        1        1        1  ...      4      1      3       1    296
# 3     2015    76        1        1        1  ...      4      1      4       1    296
# 4     2015    76        1        1        1  ...      4      1      5       1    296
#
# [5 rows x 181 columns]

# %%
dados.describe()
# Out:
#        ANOPESQ     PAIS       REGEOGR  ...         aluno        escola         turma
# count  16556.0  16556.0  16556.000000  ...  16556.000000  16556.000000  16556.000000
# mean    2015.0     76.0      3.012443  ...   8278.500000    186.053938    320.036241
# std        0.0      0.0      1.414031  ...   4779.449864    107.358284    186.022453
# min     2015.0     76.0      1.000000  ...      1.000000      1.000000      1.000000
# 25%     2015.0     76.0      2.000000  ...   4139.750000     97.000000    159.000000
# 50%     2015.0     76.0      3.000000  ...   8278.500000    184.000000    316.000000
# 75%     2015.0     76.0      4.000000  ...  12417.250000    276.000000    475.000000
# max     2015.0     76.0      5.000000  ...  16556.000000    371.000000    653.000000
#
# [8 rows x 181 columns]

# %%
zip.namelist()
# Out:
# ['arquivos csv/',
#  'arquivos csv/PENSE_AMOSTRA2_ALUNO.CSV',
#  'arquivos csv/PENSE_AMOSTRA2_ALUNOESCOLA.CSV',
#  'arquivos csv/PENSE_AMOSTRA2_ESCOLA.CSV',
#  'arquivos sas/',
#  'arquivos sas/pense_amostra2_aluno.sas7bdat',
#  'arquivos sas/pense_amostra2_alunoescola.sas7bdat',
#  'arquivos sas/pense_amostra2_escola.sas7bdat',
#  'arquivos xlsx/',
#  'arquivos xlsx/PENSE_AMOSTRA2_ALUNO.xlsx',
#  'arquivos xlsx/PENSE_AMOSTRA2_ALUNOESCOLA.xlsx',
#  'arquivos xlsx/PENSE_AMOSTRA2_ESCOLA.xlsx',
#  'Dicionario_PENSE_Microdados_AMOSTRA2.xls']

# %%
caminho_pasta_zipada_dicio = zip.namelist()[-1]
dicionario = pd.ExcelFile(zip.open(caminho_pasta_zipada_dicio))
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-15-d8e28d311282> in <module>()
#       1 caminho_pasta_zipada_dicio = zip.namelist()[-1]
# ----> 2 dicionario = pd.ExcelFile(zip.open(caminho_pasta_zipada_dicio))
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine)
#     849             engine = "xlrd"
#     850             if isinstance(path_or_buffer, (BufferedIOBase, RawIOBase)):
# --> 851                 if _is_ods_stream(path_or_buffer):
#     852                     engine = "odf"
#     853             else:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/excel/_base.py in _is_ods_stream(stream)
#     798         Boolean indication that this is indeed an ODS file or not
#     799     """
# --> 800     stream.seek(0)
#     801     is_ods = False
#     802     if stream.read(4) == b"PK\003\004":
#
# ...

# %%
dictio = pd.ExcelFile(r"/content/drive/MyDrive/Bootcamp_ALURA/Portifolio-Alura/Diário/Módulo 3/Bases de Dados/DICIONARIO_PENSE.xlsx")

# %%
dictio_aluno = dictio.parse(sheetname='AMOSTRA2_ALUNO')
dictio_escola = dictio.parse(sheetname='AMOSTRA2_ESCOLA')

# %%
dictio_aluno
# Out:
#      VARIÁVEL                   QUESTIONÁRIO DO ALUNO
# 0     ANOPESQ     Ano em que a pesquisa foi realizada
# 1        PAIS                                    País
# 2          76                                  Brasil
# 3     REGEOGR                       Região geográfica
# 4           1                                   Norte
# ...       ...                                     ...
# 1213        3                            Confessional
# 1214        4                            Filantrópica
# 1215    aluno                       contador de aluno
# 1216   escola    UPA (unidade primária de amostragem)
# 1217    turma  USA (unidade secundária de amostragem)
#
# [1218 rows x 2 columns]

# %%
dados[['VB17003', 'VB17004']]
# Out:
#        VB17003  VB17004
# 0         37.1    157.0
# 1         50.2    152.0
# 2         48.2    161.4
# 3         69.4    172.5
# 4         78.9    167.5
# ...        ...      ...
# 16551     56.7    167.9
# 16552     61.9    185.8
# 16553     60.9    159.4
# 16554     47.3    157.8
# 16555     62.6    163.9
#
# [16556 rows x 2 columns]
